# %% [markdown]
# # Fast Agent - Build a SQL Agent fast!
#
# <img src="./assets/LC_L1_Top.png" align="left" width="500">

# %% [markdown]
# ## Setup

# %% [markdown]
# Load and/or check for needed environmental variables

# %%
from dotenv import load_dotenv
from env_utils import doublecheck_env, doublecheck_pkgs

# Load environment variables from .env
load_dotenv()

# Check and print results
doublecheck_env("example.env")  # check environmental variables
doublecheck_pkgs(pyproject_path="pyproject.toml", verbose=True)   # check packages
# Out:
# DEEPSEEK_API_KEY=****daea
# LANGSMITH_API_KEY=****0714
# LANGSMITH_TRACING=true
# LANGSMITH_PROJECT=****ials
# Python 3.12.12 satisfies requires-python: >=3.11,<3.14
# package                | required | installed | status | path
# ---------------------- | -------- | --------- | ------ | -----------------------------------------------------------------------------
# langgraph              | >=1.0.0  | 1.0.6     | ✅ OK   | /home/zlzhangn/miniconda3/envs/langchain_learner/lib/python3.12/site-packages
# langchain              | >=1.0.0  | 1.2.6     | ✅ OK   | /home/zlzhangn/miniconda3/envs/langchain_learner/lib/python3.12/site-packages
# langchain-core         | >=1.0.0  | 1.2.7     | ✅ OK   | /home/zlzhangn/miniconda3/envs/langchain_learner/lib/python3.12/site-packages
# langchain-openai       | >=1.0.0  | 1.1.7     | ✅ OK   | /home/zlzhangn/miniconda3/envs/langchain_learner/lib/python3.12/site-packages
# langchain-anthropic    | >=1.0.0  | 1.3.1     | ✅ OK   | /home/zlzhangn/miniconda3/envs/langchain_learner/lib/python3.12/site-packages
# langchain-community    | >=0.4    | 0.4.1     | ✅ OK   | /home/zlzhangn/miniconda3/envs/langchain_learner/lib/python3.12/site-packages
# jupyter                | >=1.0.0  | 1.1.1     | ✅ OK   | /home/zlzhangn/miniconda3/envs/langchain_learner/lib/python3.12/site-packages
# langgraph-cli          | >=0.4.0  | 0.4.11    | ✅ OK   | /home/zlzhangn/miniconda3/envs/langchain_learner/lib/python3.12/site-packages
# langchain-mcp-adapters | (any)    | 0.2.1     | ✅ OK   | /home/zlzhangn/miniconda3/envs/langchain_learner/lib/python3.12/site-packages
#
# Environment:
# - Executable: /home/zlzhangn/miniconda3/envs/langchain_learner/bin/python

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///Chinook.db")

# %% [markdown]
# Define the runtime context to provide the agent and tools with access to the database.

# %%
from dataclasses import dataclass

from langchain_community.utilities import SQLDatabase


# define context structure to support dependency injection
@dataclass
class RuntimeContext:
    db: SQLDatabase

# %% [markdown]
# <b>⚠️ Security Note:</b> This demo does not include a filter on LLM-generated commands. In production, you would want to limit the scope of LLM-generated commands. ⚠️
# This tool will connect to the database. Note the use of `get_runtime` to access the graph **runtime context**.

# %%
from langchain_core.tools import tool
from langgraph.runtime import get_runtime

@tool
def execute_sql(query: str) -> str:
    """Execute a SQLite command and return results."""
    runtime = get_runtime(RuntimeContext)
    db = runtime.context.db

    try:
        return db.run(query)
    except Exception as e:
        return f"Error: {e}"

# %% [markdown]
# Add a system prompt to define your agents behavior.

# %%
SYSTEM_PROMPT = """You are a careful SQLite analyst.

Rules:
- Think step-by-step.
- When you need data, call the tool `execute_sql` with ONE SELECT query.
- Read-only only; no INSERT/UPDATE/DELETE/ALTER/DROP/CREATE/REPLACE/TRUNCATE.
- Limit to 5 rows of output unless the user explicitly asks otherwise.
- If the tool returns 'Error:', revise the SQL and try again.
- Prefer explicit column lists; avoid SELECT *.
"""

# %% [markdown]
# Create your agent! Add a model, tools, a prompt, and the runtime access, and go!  You can choose many agents from our [integrations](https://docs.langchain.com/oss/python/integrations/providers) list.
#
# Agent支持的模型 https://docs.langchain.com/oss/python/langchain/agents

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="deepseek-chat",
    tools=[execute_sql],
    system_prompt=SYSTEM_PROMPT,
    context_schema=RuntimeContext
)

# %% [markdown]
# Here's a display of the agent ReAct Loop.

# %%
from IPython.display import Image, display

display(Image(agent.get_graph(xray=True).draw_mermaid_png()))

# %% [markdown]
# Run some queries. Notice:
# - The agent does not have the database schema and will need to discover it independently.
# - The agent may make mistakes! By returning error messages, the agent can self-correct its queries.
# - Notice you invoke the agent with `agent.stream`.
#     - This command and the `pretty_print` display the **messages** that communicate information between the model and the tools.
# - Notice the agent doesn't remember the schema between invocations... More on this later!

# %%
question = "Which table has the largest number of entries?"

for step in agent.stream(
    {"messages": question},
    context=RuntimeContext(db=db),
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Which table has the largest number of entries?
# ================================== Ai Message ==================================
#
# I'll help you find which table has the largest number of entries. First, let me get a list of all tables in the database.
# Tool Calls:
#   execute_sql (call_00_n9btKEoxkyX59Zg0e8SFWPz0)
#  Call ID: call_00_n9btKEoxkyX59Zg0e8SFWPz0
#   Args:
#     query: SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# ================================= Tool Message =================================
# Name: execute_sql
#
# [('Album',), ('Artist',), ('Customer',), ('Employee',), ('Genre',), ('Invoice',), ('InvoiceLine',), ('MediaType',), ('Playlist',), ('PlaylistTrack',), ('Track',)]
# ================================== Ai Message ==================================
#
# Now I'll count the number of entries in each table to find which one has the largest number of entries.
# Tool Calls:
#   execute_sql (call_00_Qi7jll8ab0gz14llxepkNZHP)
#  Call ID: call_00_Qi7jll8ab0gz14llxepkNZHP
#   Args:
#     query: SELECT
#     'Album' as table_name,
#     COUNT(*) as entry_count
# FROM Album
# UNION ALL
# SELECT
#     'Artist' as table_name,
#     COUNT(*) as entry_count
# FROM Artist
# UNION ALL
# SELECT
#     'Customer' as table_name,
#     COUNT(*) as entry_count
# FROM Customer
# UNION ALL
# SELECT
#     'Employee' as table_name,
#     COUNT(*) as entry_count
# FROM Employee
# UNION ALL
# SELECT
#     'Genre' as table_name,
#     COUNT(*) as entry_count
# FROM Genre
# UNION ALL
# SELECT
#     'Invoice' as table_name,
#     COUNT(*) as entry_count
# FROM Invoice
# UNION ALL
# SELECT
#     'InvoiceLine' as table_name,
#     COUNT(*) as entry_count
# FROM InvoiceLine
# UNION ALL
# SELECT
#     'MediaType' as table_name,
#     COUNT(*) as entry_count
# FROM MediaType
# UNION ALL
# SELECT
#     'Playlist' as table_name,
#     COUNT(*) as entry_count
# FROM Playlist
# UNION ALL
# SELECT
#     'PlaylistTrack' as table_name,
#     COUNT(*) as entry_count
# FROM PlaylistTrack
# UNION ALL
# SELECT
#     'Track' as table_name,
#     COUNT(*) as entry_count
# FROM Track
# ORDER BY entry_count DESC
# ================================= Tool Message =================================
# Name: execute_sql
#
# [('PlaylistTrack', 8715), ('Track', 3503), ('InvoiceLine', 2240), ('Invoice', 412), ('Album', 347), ('Artist', 275), ('Customer', 59), ('Genre', 25), ('Playlist', 18), ('Employee', 8), ('MediaType', 5)]
# ================================== Ai Message ==================================
#
# Based on the results, the **PlaylistTrack** table has the largest number of entries with **8,715 entries**.
#
# Here's the complete ranking of tables by entry count:
# 1. **PlaylistTrack**: 8,715 entries
# 2. Track: 3,503 entries
# 3. InvoiceLine: 2,240 entries
# 4. Invoice: 412 entries
# 5. Album: 347 entries
# 6. Artist: 275 entries
# 7. Customer: 59 entries
# 8. Genre: 25 entries
# 9. Playlist: 18 entries
# 10. Employee: 8 entries
# 11. MediaType: 5 entries

# %%
question = "Which genre on average has the longest tracks?"

for step in agent.stream(
    {"messages": question},
    context=RuntimeContext(db=db),
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Which genre on average has the longest tracks?
# ================================== Ai Message ==================================
#
# I'll help you find which genre on average has the longest tracks. Let me start by exploring the database structure to understand what tables are available.
# Tool Calls:
#   execute_sql (call_00_xin3UnmUBU4tyTCrAe894rhb)
#  Call ID: call_00_xin3UnmUBU4tyTCrAe894rhb
#   Args:
#     query: SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;
# ================================= Tool Message =================================
# Name: execute_sql
#
# [('Album',), ('Artist',), ('Customer',), ('Employee',), ('Genre',), ('Invoice',), ('InvoiceLine',), ('MediaType',), ('Playlist',), ('PlaylistTrack',), ('Track',)]
# ================================== Ai Message ==================================
#
# Good, I can see there are tables for `Genre` and `Track`. Let me examine the structure of these tables to understand their relationships and columns.
# Tool Calls:
#   execute_sql (call_00_0DgAmFLtpTvvxWFIWvcpDPuG)
#  Call ID: call_00_0DgAmFLtpTvvxWFIWvcpDPuG
#   Args:
#     query: PRAGMA table_info(Genre);
# ================================= Tool Message =================================
# Name: execute_sql
#
# [(0, 'GenreId', 'INTEGER', 1, None, 1), (1, 'Name', 'NVARCHAR(120)', 0, None, 0)]
# ================================== Ai Message ==================================
# Tool Calls:
#   execute_sql (call_00_QqQr2eY4LEehn6YVVVdP8geT)
#  Call ID: call_00_QqQr2eY4LEehn6YVVVdP8geT
#   Args:
#     query: PRAGMA table_info(Track);
# ================================= Tool Message =================================
# Name: execute_sql
#
# [(0, 'TrackId', 'INTEGER', 1, None, 1), (1, 'Name', 'NVARCHAR(200)', 1, None, 0), (2, 'AlbumId', 'INTEGER', 0, None, 0), (3, 'MediaTypeId', 'INTEGER', 1, None, 0), (4, 'GenreId', 'INTEGER', 0, None, 0), (5, 'Composer', 'NVARCHAR(220)', 0, None, 0), (6, 'Milliseconds', 'INTEGER', 1, None, 0), (7, 'Bytes', 'INTEGER', 0, None, 0), (8, 'UnitPrice', 'NUMERIC(10,2)', 1, None, 0)]
# ================================== Ai Message ==================================
#
# Perfect! I can see that:
# - The `Track` table has a `GenreId` column that links to the `Genre` table
# - The `Track` table has a `Milliseconds` column which represents the track length
# - The `Genre` table has `GenreId` and `Name` columns
#
# Now I need to calculate the average track length for each genre. Let me write a query to join the tables and calculate the average track length in milliseconds for each genre.
# Tool Calls:
#   execute_sql (call_00_wySVN3nAQIrBEUtz5WsfsDfJ)
#  Call ID: call_00_wySVN3nAQIrBEUtz5WsfsDfJ
#   Args:
#     query: SELECT
#     g.Name AS GenreName,
#     COUNT(t.TrackId) AS TrackCount,
#     AVG(t.Milliseconds) AS AvgMilliseconds,
#     AVG(t.Milliseconds) / 1000.0 AS AvgSeconds,
#     AVG(t.Milliseconds) / 60000.0 AS AvgMinutes
# FROM Genre g
# LEFT JOIN Track t ON g.GenreId = t.GenreId
# GROUP BY g.GenreId, g.Name
# HAVING COUNT(t.TrackId) > 0
# ORDER BY AvgMilliseconds DESC
# LIMIT 10;
# ================================= Tool Message =================================
# Name: execute_sql
#
# [('Sci Fi & Fantasy', 26, 2911783.0384615385, 2911.7830384615386, 48.52971730769231), ('Science Fiction', 13, 2625549.076923077, 2625.549076923077, 43.759151282051285), ('Drama', 64, 2575283.78125, 2575.28378125, 42.92139635416667), ('TV Shows', 93, 2145041.0215053763, 2145.041021505376, 35.75068369175627), ('Comedy', 17, 1585263.705882353, 1585.263705882353, 26.421061764705883), ('Metal', 374, 309749.4438502674, 309.74944385026737, 5.162490730837789), ('Electronica/Dance', 30, 302985.8, 302.9858, 5.049763333333333), ('Heavy Metal', 28, 297452.9285714286, 297.4529285714286, 4.95754880952381), ('Classical', 74, 293867.5675675676, 293.86756756756756, 4.897792792792793), ('Jazz', 130, 291755.3769230769, 291.75537692307694, 4.862589615384615)]
# ================================== Ai Message ==================================
#
# Interesting! The results show that "Sci Fi & Fantasy" has the highest average track length at about 48.5 minutes per track. However, these averages seem unusually high - 48 minutes per track for Sci Fi & Fantasy seems like it might be including audiobooks or other long-form content rather than typical music tracks.
#
# Let me check the actual track lengths for the Sci Fi & Fantasy genre to understand this better:
# Tool Calls:
#   execute_sql (call_00_o7ad8iC78y5VG7EWCobYEIfN)
#  Call ID: call_00_o7ad8iC78y5VG7EWCobYEIfN
#   Args:
#     query: SELECT
#     t.Name AS TrackName,
#     t.Milliseconds,
#     t.Milliseconds / 1000.0 AS Seconds,
#     t.Milliseconds / 60000.0 AS Minutes
# FROM Track t
# JOIN Genre g ON t.GenreId = g.GenreId
# WHERE g.Name = 'Sci Fi & Fantasy'
# ORDER BY t.Milliseconds DESC
# LIMIT 10;
# ================================= Tool Message =================================
# Name: execute_sql
#
# [('Greetings from Earth, Pt. 1', 2960293, 2960.293, 49.33821666666667), ('The Man With Nine Lives', 2956998, 2956.998, 49.2833), ('Battlestar Galactica, Pt. 2', 2956081, 2956.081, 49.26801666666667), ('Battlestar Galactica, Pt. 1', 2952702, 2952.702, 49.2117), ('Murder On the Rising Star', 2935894, 2935.894, 48.93156666666667), ('Battlestar Galactica, Pt. 3', 2927802, 2927.802, 48.7967), ('Take the Celestra', 2927677, 2927.677, 48.79461666666667), ('Fire In Space', 2926593, 2926.593, 48.77655), ('The Long Patrol', 2925008, 2925.008, 48.75013333333333), ('The Magnificent Warriors', 2924716, 2924.716, 48.745266666666666)]
# ================================== Ai Message ==================================
#
# Now I see! These are indeed very long tracks - around 49 minutes each. These appear to be episodes or chapters from audiobooks or radio dramas rather than typical music tracks. Let me check a few more genres to compare:
# Tool Calls:
#   execute_sql (call_00_EeWDJy5kg0mQlopB1C5llgAI)
#  Call ID: call_00_EeWDJy5kg0mQlopB1C5llgAI
#   Args:
#     query: SELECT
#     g.Name AS GenreName,
#     COUNT(t.TrackId) AS TrackCount,
#     AVG(t.Milliseconds) AS AvgMilliseconds,
#     AVG(t.Milliseconds) / 60000.0 AS AvgMinutes
# FROM Genre g
# LEFT JOIN Track t ON g.GenreId = t.GenreId
# GROUP BY g.GenreId, g.Name
# HAVING COUNT(t.TrackId) > 0
# ORDER BY AvgMilliseconds DESC;
# ================================= Tool Message =================================
# Name: execute_sql
#
# [('Sci Fi & Fantasy', 26, 2911783.0384615385, 48.52971730769231), ('Science Fiction', 13, 2625549.076923077, 43.759151282051285), ('Drama', 64, 2575283.78125, 42.92139635416667), ('TV Shows', 93, 2145041.0215053763, 35.75068369175627), ('Comedy', 17, 1585263.705882353, 26.421061764705883), ('Metal', 374, 309749.4438502674, 5.162490730837789), ('Electronica/Dance', 30, 302985.8, 5.049763333333333), ('Heavy Metal', 28, 297452.9285714286, 4.95754880952381), ('Classical', 74, 293867.5675675676, 4.897792792792793), ('Jazz', 130, 291755.3769230769, 4.862589615384615), ('Rock', 1297, 283910.0431765613, 4.7318340529426886), ('Blues', 81, 270359.77777777775, 4.505996296296296), ('Alternative', 40, 264058.525, 4.400975416666667), ('Reggae', 58, 247177.75862068965, 4.119629310344828), ('Soundtrack', 43, 244370.88372093023, 4.072848062015503), ('Alternative & Punk', 332, 234353.84939759035, 3.9058974899598393), ('Latin', 579, 232859.26252158894, 3.8809877086931492), ('Pop', 48, 229034.10416666666, 3.817235069444444), ('World', 28, 224923.82142857142, 3.748730357142857), ('R&B/Soul', 61, 220066.8524590164, 3.66778087431694), ('Bossa Nova', 15, 219590.0, 3.6598333333333333), ('Easy Listening', 24, 189164.20833333334, 3.1527368055555556), ('Hip Hop/Rap', 35, 178176.2857142857, 2.969604761904762), ('Opera', 1, 174813.0, 2.91355), ('Rock And Roll', 12, 134643.5, 2.2440583333333333)]
# ================================== Ai Message ==================================
#
# Now I have the complete picture. Looking at all genres, I can see that:
#
# 1. **Top 5 genres with longest average track length:**
#    - Sci Fi & Fantasy: 48.53 minutes
#    - Science Fiction: 43.76 minutes
#    - Drama: 42.92 minutes
#    - TV Shows: 35.75 minutes
#    - Comedy: 26.42 minutes
#
# 2. **More traditional music genres:**
#    - Metal: 5.16 minutes
#    - Electronica/Dance: 5.05 minutes
#    - Heavy Metal: 4.96 minutes
#    - Classical: 4.90 minutes
#    - Jazz: 4.86 minutes
#    - Rock: 4.73 minutes
#
# The top genres (Sci Fi & Fantasy, Science Fiction, Drama, TV Shows, Comedy) appear to contain audiobooks, radio dramas, or other spoken-word content rather than traditional music tracks, which explains their much longer average durations.
#
# **Answer:** The genre with the longest average track length is **"Sci Fi & Fantasy"** with an average of approximately **48.53 minutes per track**. However, it's important to note that these top genres contain spoken-word content rather than traditional music. Among more traditional music genres, **"Metal"** has the longest average track length at approximately **5.16 minutes per track**.

# %%
question = "Please list all of the tables"

for step in agent.stream(
    {"messages": question},
    context={"db": db},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Please list all of the tables
# ================================== Ai Message ==================================
#
# I'll help you list all the tables in the database. Let me query the SQLite system tables to get this information.
# Tool Calls:
#   execute_sql (call_00_KO7XUGdCQrS1hMGB2AvNrl0O)
#  Call ID: call_00_KO7XUGdCQrS1hMGB2AvNrl0O
#   Args:
#     query: SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# ================================= Tool Message =================================
# Name: execute_sql
#
# [('Album',), ('Artist',), ('Customer',), ('Employee',), ('Genre',), ('Invoice',), ('InvoiceLine',), ('MediaType',), ('Playlist',), ('PlaylistTrack',), ('Track',)]
# ================================== Ai Message ==================================
#
# Here are all the tables in the database:
#
# 1. **Album** - Likely contains information about music albums
# 2. **Artist** - Likely contains information about music artists
# 3. **Customer** - Likely contains customer information
# 4. **Employee** - Likely contains employee information
# 5. **Genre** - Likely contains music genre information
# 6. **Invoice** - Likely contains invoice/sales information
# 7. **InvoiceLine** - Likely contains line items from invoices
# 8. **MediaType** - Likely contains media type information (CD, MP3, etc.)
# 9. **Playlist** - Likely contains playlist information
# 10. **PlaylistTrack** - Likely contains the relationship between playlists and tracks
# 11. **Track** - Likely contains information about individual music tracks
#
# This appears to be a music store or music library database with tables for managing artists, albums, tracks, customers, sales, and playlists.

# %% [markdown]
# **Create your own query here!**  Add some questions of your own.

# %%
question = "TRY YOUR OWN QUERY HERE"

for step in agent.stream(
    {"messages": question},
    context={"db": db},
    stream_mode="values",
):
    step["messages"][-1].pretty_print()

# %% [markdown]
# ### Let's try this Studio
