# %% [markdown]
# # Tracing Basics

# %% [markdown]
# ### Setup

# %% [markdown]
# Make sure you set your environment variables, including your OpenAI API key.

# %%
# You can set them inline
import os
os.environ["OPENAI_API_KEY"] = ""
os.environ["LANGSMITH_API_KEY"] = ""
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langsmith-academy"
# Out:
#   true langsmith-academy

# %%
# Or you can use a .env file
from dotenv import load_dotenv
load_dotenv(dotenv_path="../../../.env", override=True)
# Out:
# https://api.openai-proxy.org/v1

# %% [markdown]
# ### Tracing with @traceable

# %% [markdown]
# The @traceable decorator is a simple way to log traces from the LangSmith Python SDK. Simply decorate any function with @traceable.
#
# The decorator works by creating a run tree for you each time the function is called and inserting it within the current trace. The function inputs, name, and other information is then streamed to LangSmith. If the function raises an error or if it returns a response, that information is also added to the tree, and updates are patched to LangSmith so you can detect and diagnose sources of errors. This is all done on a background thread to avoid blocking your app's execution.

# %%
from langsmith import traceable
from openai import OpenAI
from typing import List
import nest_asyncio
from utils import get_vector_db_retriever

MODEL_PROVIDER = "openai"
MODEL_NAME = "gpt-4o-mini"
APP_VERSION = 1.0
RAG_SYSTEM_PROMPT = """You are an assistant for question-answering tasks. 
Use the following pieces of retrieved context to answer the latest question in the conversation. 
If you don't know the answer, just say that you don't know. 
Use three sentences maximum and keep the answer concise.
"""

openai_client = OpenAI()
result = openai_client.chat.completions.create(
        model='gpt-4o',
        messages=["你是谁？"],
        temperature=0.5,
    )
print(result.choices[0].message.content)
nest_asyncio.apply()
retriever = get_vector_db_retriever()

@traceable
def retrieve_documents(question: str):
    return retriever.invoke(question)   # NOTE: This is a LangChain vector db retriever, so this .invoke() call will be traced automatically


@traceable
def generate_response(question: str, documents):
    formatted_docs = "\n\n".join(doc.page_content for doc in documents)
    messages = [
        {
            "role": "system",
            "content": RAG_SYSTEM_PROMPT
        },
        {
            "role": "user",
            "content": f"Context: {formatted_docs} \n\n Question: {question}"
        }
    ]
    return call_openai(messages)


@traceable
def call_openai(
    messages: List[dict], model: str = MODEL_NAME, temperature: float = 0.0
) -> str:
    return openai_client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
    )


@traceable
def langsmith_rag(question: str):
    documents = retrieve_documents(question)
    response = generate_response(question, documents)
    return response.choices[0].message.content
# Out:
# Fetching pages: 100%|##########| 367/367 [01:40<00:00,  3.66it/s]
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[19], line 18
#      16 openai_client = OpenAI()
#      17 nest_asyncio.apply()
# ---> 18 retriever = get_vector_db_retriever()
#      20 @traceable
#      21 def retrieve_documents(question: str):
#      22     return retriever.invoke(question)   # NOTE: This is a LangChain vector db retriever, so this .invoke() call will be traced automatically
#
# File ~/projects/langchain_learner/intro-to-langsmith/notebooks/module_1/utils.py:44, in get_vector_db_retriever()
#      39 text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
#      40     chunk_size=500, chunk_overlap=0
#      41 )
#      42 doc_splits = text_splitter.split_documents(ls_docs)
# ---> 44 vectorstore = SKLearnVectorStore.from_documents(
#      45     documents=doc_splits,
#      46     embedding=embd,
#      47     persist_path=persist_path,
#      48     serializer="parquet"
#      49 )
#      50 vectorstore.persist()
#      51 return vectorstore.as_retriever(lambda_mult=0)
#
# File ~/miniconda3/envs/langchain_learner/lib/python3.12/site-packages/langchain_core/vectorstores/base.py:814, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     811     if any(ids):
#     812         kwargs["ids"] = ids
# --> 814 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File ~/miniconda3/envs/langchain_learner/lib/python3.12/site-packages/langchain_community/vectorstores/sklearn.py:353, in SKLearnVectorStore.from_texts(cls, texts, embedding, metadatas, ids, persist_path, **kwargs)
#     342 @classmethod
#     343 def from_texts(
#     344     cls,
#    (...)    350     **kwargs: Any,
#     351 ) -> "SKLearnVectorStore":
#     352     vs = SKLearnVectorStore(embedding, persist_path=persist_path, **kwargs)
# --> 353     vs.add_texts(texts, metadatas=metadatas, ids=ids)
#     354     return vs
#
# File ~/miniconda3/envs/langchain_learner/lib/python3.12/site-packages/langchain_community/vectorstores/sklearn.py:206, in SKLearnVectorStore.add_texts(self, texts, metadatas, ids, **kwargs)
#     204 _ids = ids or [str(uuid4()) for _ in _texts]
#     205 self._texts.extend(_texts)
# --> 206 self._embeddings.extend(self._embedding_function.embed_documents(_texts))
#     207 self._metadatas.extend(metadatas or ([{}] * len(_texts)))
#     208 self._ids.extend(_ids)
#
# File ~/miniconda3/envs/langchain_learner/lib/python3.12/site-packages/langchain_openai/embeddings/base.py:751, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     748 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     749 # This could be optimized to avoid double work when all texts are short enough.
#     750 engine = cast(str, self.deployment)
# --> 751 return self._get_len_safe_embeddings(
#     752     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     753 )
#
# File ~/miniconda3/envs/langchain_learner/lib/python3.12/site-packages/langchain_openai/embeddings/base.py:618, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     616 # Make API call with this batch
#     617 batch_tokens = tokens[i:batch_end]
# --> 618 response = self.client.create(input=batch_tokens, **client_kwargs)
#     619 if not isinstance(response, dict):
#     620     response = response.model_dump()
#
# File ~/miniconda3/envs/langchain_learner/lib/python3.12/site-packages/openai/resources/embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File ~/miniconda3/envs/langchain_learner/lib/python3.12/site-packages/openai/_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniconda3/envs/langchain_learner/lib/python3.12/site-packages/openai/_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': '用户未认证，请携带token访问', 'type': 'error'}}

# %% [markdown]
# @traceable handles the RunTree lifecycle for you!

# %%
question = "How can I trace with the @traceable decorator?"
ai_answer = langsmith_rag(question)
print(ai_answer)

# %% [markdown]
# ##### Let's take a look in LangSmith!

# %% [markdown]
# ### Adding Metadata

# %% [markdown]
# LangSmith supports sending arbitrary metadata along with traces.
#
# Metadata is a collection of key-value pairs that can be attached to runs. Metadata can be used to store additional information about a run, such as the version of the application that generated the run, the environment in which the run was generated, or any other information that you want to associate with a run. Similar to tags, you can use metadata to filter runs in the LangSmith UI, and can be used to group runs together for analysis.

# %%
from langsmith import traceable

@traceable(
    # TODO: Add Metadata
    # metadata={"vectordb": "sklearn"}
)
def retrieve_documents(question: str):
    return retriever.invoke(question)

@traceable
def generate_response(question: str, documents):
    formatted_docs = "\n\n".join(doc.page_content for doc in documents)
    messages = [
        {
            "role": "system",
            "content": RAG_SYSTEM_PROMPT
        },
        {
            "role": "user",
            "content": f"Context: {formatted_docs} \n\n Question: {question}"
        }
    ]
    return call_openai(messages)

@traceable(
    # TODO: Add Metadata
    # metadata={"model_name": MODEL_NAME, "model_provider": MODEL_PROVIDER}
)
def call_openai(
    messages: List[dict], model: str = MODEL_NAME, temperature: float = 0.0
) -> str:
    return openai_client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=temperature,
    )

@traceable
def langsmith_rag(question: str):
    documents = retrieve_documents(question)
    response = generate_response(question, documents)
    return response.choices[0].message.content

# %%
question = "How do I add Metadata to a Run with @traceable?"
ai_answer = langsmith_rag(question)
print(ai_answer)

# %% [markdown]
# You can also add metadata at runtime!

# %%
question = "How do I add metadata at runtime?"
ai_answer = langsmith_rag(question, langsmith_extra={"metadata": {"runtime_metadata": "foo"}})
print(ai_answer)

# %% [markdown]
# ##### Let's take a look in LangSmith!
